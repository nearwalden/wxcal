# %%
import pandas as p

# %%
import new_leap

# %%
import files

# %%
import daily

# %%
import importlib

# %%
importlib.reload(new_leap)
# Out:
# <module 'new_leap' from '/mnt/c/Users/nearw/gitcode/wxcal/new_leap.py'>

# %%
new_leap.process()
# Out:
# processed 25N_114W
# processed 25N_109W
# processed 25N_104W
# processed 25N_99W
# processed 25N_84W
# processed 30N_119W
# processed 30N_114W
# processed 30N_109W
# processed 30N_104W
# processed 30N_99W
# processed 30N_94W
# processed 30N_89W
# processed 30N_84W
# processed 30N_79W
# processed 35N_119W
# processed 35N_114W
# processed 35N_109W
# processed 35N_104W
# processed 35N_99W
# processed 35N_94W
# processed 35N_89W
# processed 35N_84W
# processed 35N_79W
# processed 40N_119W
# processed 40N_114W
# processed 40N_109W
# processed 40N_104W
# processed 40N_99W
# processed 40N_94W
# processed 40N_89W
# processed 40N_84W
# processed 40N_79W
# processed 40N_74W
# processed 40N_69W
# processed 45N_119W
# processed 45N_114W
# processed 45N_109W
# processed 45N_104W
# processed 45N_99W
# processed 45N_94W
# processed 45N_89W
# processed 45N_84W
# processed 45N_79W
# processed 45N_74W
# processed 45N_69W
# True

# %%
new_leap.is_leap_year(1880)
# Out:
# True

# %%
new_leap.plot_loc(25, -104, start=2008, end=2020)

# %%
new_leap.plot_delta(25, -114, start=1900, end=2001)

# %%
new = p.read_csv(new_leap.OUT_DIR + 'new_leap_yr.csv')

# %%
normd = new_leap.four_year_stats(norm)

# %%
normd
# Out:
#        sum  25N_114W  25N_109W  25N_104W   25N_99W   25N_84W  30N_119W  \
# year4
# 0.0    NaN  0.049917 -0.059132 -0.043012 -0.075030 -0.212135  0.092188
# 1.0    NaN -0.026802  0.075180  0.170431  0.158133  0.218737 -0.039654
# 2.0    NaN  0.209837  0.170852  0.063588  0.042858 -0.054447  0.170177
# 3.0    NaN -0.173908 -0.134856 -0.137180 -0.054227  0.139998 -0.155491
#
#        30N_114W  30N_109W  30N_104W  ...  45N_114W  45N_109W  45N_104W  \
# year4                                ...
# 0.0    0.068609 -0.050034 -0.028337  ...  0.032263 -0.011877 -0.075584
# 1.0    0.023832  0.108870  0.045036  ... -0.044692 -0.011727  0.030345
# 2.0    0.203915  0.203288  0.183690  ...  0.222980  0.171011  0.159150
# 3.0   -0.228511 -0.207797 -0.154559  ... -0.182877 -0.123559 -0.083265
#
#         45N_99W   45N_94W   45N_89W   45N_84W   45N_79W   45N_74W   45N_69W
# year4
# 0.0   -0.181495 -0.258300 -0.295923 -0.341876 -0.294688 -0.261190 -0.187483
# ...

# %%
newd
# Out:
#        sum  25N_114W  25N_109W  25N_104W   25N_99W   25N_84W  30N_119W  \
# year4
# 0.0    NaN  0.071697 -0.038375 -0.021691 -0.055086 -0.196482  0.119226
# 1.0    NaN -0.048582  0.054424  0.149111  0.138189  0.203084 -0.066692
# 2.0    NaN  0.209837  0.170852  0.063588  0.042858 -0.054447  0.170177
# 3.0    NaN -0.173908 -0.134856 -0.137180 -0.054227  0.139998 -0.155491
#
#        30N_114W  30N_109W  30N_104W  ...  45N_114W  45N_109W  45N_104W  \
# year4                                ...
# 0.0    0.096276 -0.022225 -0.001074  ...  0.069166  0.033525 -0.025395
# 1.0   -0.003836  0.081061  0.017773  ... -0.081595 -0.057130 -0.019844
# 2.0    0.203915  0.203288  0.183690  ...  0.222980  0.171011  0.159150
# 3.0   -0.228511 -0.207797 -0.154559  ... -0.182877 -0.123559 -0.083265
#
#         45N_99W   45N_94W   45N_89W   45N_84W   45N_79W   45N_74W   45N_69W
# year4
# 0.0   -0.129747 -0.211662 -0.251707 -0.296623 -0.249891 -0.217610 -0.147936
# ...

# %%
daily.four_year_stats_day()
# Out:
#           temp
# year
# 1901 -0.144049
# 1902 -0.382156
# 1903 -0.450288
# 1904 -0.606874
# 1905 -0.458496
# ...        ...
# 2014  0.947268
# 2015  1.216375
# 2016  1.382836
# 2017  1.279797
# 2018  1.143532
#
# [118 rows x 1 columns]
#            diff
# year4
# 0     -0.107863
# 1      0.086195
# 2      0.024443
# 3      0.040782

# %%
daily.four_year_stats_year('air_anomaly')
# Out:
#            diff
# year4
# 0     -0.027367
# 1      0.044897
# 2      0.010633
# 3      0.014933

# %%
importlib.reload(new_leap)
# Out:
# <module 'new_leap' from '/mnt/c/Users/nearw/gitcode/wxcal/new_leap.py'>

# %%
new_leap.leap_year_delta()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-e79cd8583882> in <module>
# ----> 1 new_leap.leap_year_delta()
#
# /mnt/c/Users/nearw/gitcode/wxcal/new_leap.py in leap_year_delta()
#     204     df_out_delta.to_csv(OUT_DIR + 'leap_deltas.csv')
#     205     out = []
# --> 206     for loc in df_out_delta.columns.to_list().remove('year'):
#     207         delta = df_out_delta[loc]
#     208         delta = delta[delta != 0]
#
# TypeError: 'NoneType' object is not iterable

# %%
new_leap.compare_new()
# Out:
#          loc      mean       max
# 0   25N_114W  0.022562  0.035275
# 1   25N_109W  0.022314  0.039135
# 2   25N_104W  0.023693  0.050102
# 3    25N_99W  0.022387  0.051912
# 4    25N_84W  0.015649  0.049917
# 5   30N_119W  0.027208  0.038774
# 6   30N_114W  0.028945  0.043467
# 7   30N_109W  0.029990  0.049671
# 8   30N_104W  0.030019  0.056828
# 9    30N_99W  0.027454  0.056780
# 10   30N_94W  0.023483  0.057353
# 11   30N_89W  0.021903  0.061435
# 12   30N_84W  0.021381  0.060245
# 13   30N_79W  0.022947  0.061677
# 14  35N_119W  0.032721  0.054049
# 15  35N_114W  0.034938  0.056748
# 16  35N_109W  0.033701  0.064152
# 17  35N_104W  0.035579  0.073859
# 18   35N_99W  0.036543  0.073310
# 19   35N_94W  0.032079  0.070153
# 20   35N_89W  0.027351  0.066965
# 21   35N_84W  0.024045  0.067084
# 22   35N_79W  0.025242  0.071644
# 23  40N_119W  0.033988  0.060838
# 24  40N_114W  0.036626  0.072086
# 25  40N_109W  0.036953  0.077410
# 26  40N_104W  0.041474  0.081378
# ...
