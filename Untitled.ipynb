# %%
import pandas as p

# %%
import new_leap

# %%
import files

# %%
import daily

# %%
import importlib

# %%
importlib.reload(new_leap)
# Out:
# <module 'new_leap' from '/mnt/c/Users/nearw/gitcode/wxcal/new_leap.py'>

# %%
new_leap.process()
# Out:
# processed 25N_114W
# processed 25N_109W
# processed 25N_104W
# processed 25N_99W
# processed 25N_84W
# processed 30N_119W
# processed 30N_114W
# processed 30N_109W
# processed 30N_104W
# processed 30N_99W
# processed 30N_94W
# processed 30N_89W
# processed 30N_84W
# processed 30N_79W
# processed 35N_119W
# processed 35N_114W
# processed 35N_109W
# processed 35N_104W
# processed 35N_99W
# processed 35N_94W
# processed 35N_89W
# processed 35N_84W
# processed 35N_79W
# processed 40N_119W
# processed 40N_114W
# processed 40N_109W
# processed 40N_104W
# processed 40N_99W
# processed 40N_94W
# processed 40N_89W
# processed 40N_84W
# processed 40N_79W
# processed 40N_74W
# processed 40N_69W
# processed 45N_119W
# processed 45N_114W
# processed 45N_109W
# processed 45N_104W
# processed 45N_99W
# processed 45N_94W
# processed 45N_89W
# processed 45N_84W
# processed 45N_79W
# processed 45N_74W
# processed 45N_69W
# True

# %%
new_leap.is_leap_year(1880)
# Out:
# True

# %%
new_leap.plot_loc(45, -99, start=2008, end=2020)

# %%
new_leap.plot_delta(35, -114, start=1900, end=2001)

# %%
new_leap.plot_mean_delta(start=1900, end=2001)

# %%
new_leap.plot_mean(start=1960, end=1980, path="/mnt/c/Users/nearw/figure.png")

# %%
new = p.read_csv(new_leap.OUT_DIR + 'new_leap_yr.csv')

# %%
newd = new_leap.four_year_stats(new)

# %%
newd['mean']
# Out:
# year4
# 0.0   -0.115931
# 1.0    0.083580
# 2.0    0.142870
# 3.0   -0.056438
# Name: mean, dtype: float64

# %%
new
# Out:
#      Unnamed: 0    year   25N_114W   25N_109W   25N_104W    25N_99W  \
# 0             0  1880.0  20.900216  15.498516  19.335895  20.495218
# 1             1  1881.0  21.380751  16.046356  19.837046  20.904432
# 2             2  1882.0  21.510689  16.108242  19.761238  20.877618
# 3             3  1883.0  21.821509  16.426494  20.181541  21.289369
# 4             4  1884.0  21.669037  16.410490  19.911849  20.678602
# ..          ...     ...        ...        ...        ...        ...
# 133         133  2013.0  22.365395  17.895553  20.682812  21.770090
# 134         134  2014.0  23.367955  18.449569  20.677877  21.382555
# 135         135  2015.0  23.054297  18.273663  20.699837  21.834935
# 136         136  2016.0  23.138688  18.438193  21.467745  22.815440
# 137         137  2017.0  23.407316  18.906058  21.824901  23.028711
#
#        25N_84W   30N_119W   30N_114W   30N_109W  ...  45N_114W  45N_109W  \
# 0    22.622734  17.353212  15.794451  12.712759  ...  2.304952  3.582023
# ...

# %%
daily.four_year_stats_day()
# Out:
#           temp
# year
# 1901 -0.144049
# 1902 -0.382156
# 1903 -0.450288
# 1904 -0.606874
# 1905 -0.458496
# ...        ...
# 2014  0.947268
# 2015  1.216375
# 2016  1.382836
# 2017  1.279797
# 2018  1.143532
#
# [118 rows x 1 columns]
#            diff
# year4
# 0     -0.107863
# 1      0.086195
# 2      0.024443
# 3      0.040782

# %%
daily.four_year_stats_year('air_anomaly')
# Out:
#            diff
# year4
# 0     -0.027367
# 1      0.044897
# 2      0.010633
# 3      0.014933

# %%
importlib.reload(new_leap)
# Out:
# <module 'new_leap' from '/mnt/c/Users/nearw/gitcode/wxcal/new_leap.py'>

# %%
new_leap.leap_year_delta()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-e79cd8583882> in <module>
# ----> 1 new_leap.leap_year_delta()
#
# /mnt/c/Users/nearw/gitcode/wxcal/new_leap.py in leap_year_delta()
#     204     df_out_delta.to_csv(OUT_DIR + 'leap_deltas.csv')
#     205     out = []
# --> 206     for loc in df_out_delta.columns.to_list().remove('year'):
#     207         delta = df_out_delta[loc]
#     208         delta = delta[delta != 0]
#
# TypeError: 'NoneType' object is not iterable

# %%
new_leap.compare_new()
# Out:
#          loc      mean       max
# 0   25N_114W  0.022562  0.035275
# 1   25N_109W  0.022314  0.039135
# 2   25N_104W  0.023693  0.050102
# 3    25N_99W  0.022387  0.051912
# 4    25N_84W  0.015649  0.049917
# 5   30N_119W  0.027208  0.038774
# 6   30N_114W  0.028945  0.043467
# 7   30N_109W  0.029990  0.049671
# 8   30N_104W  0.030019  0.056828
# 9    30N_99W  0.027454  0.056780
# 10   30N_94W  0.023483  0.057353
# 11   30N_89W  0.021903  0.061435
# 12   30N_84W  0.021381  0.060245
# 13   30N_79W  0.022947  0.061677
# 14  35N_119W  0.032721  0.054049
# 15  35N_114W  0.034938  0.056748
# 16  35N_109W  0.033701  0.064152
# 17  35N_104W  0.035579  0.073859
# 18   35N_99W  0.036543  0.073310
# 19   35N_94W  0.032079  0.070153
# 20   35N_89W  0.027351  0.066965
# 21   35N_84W  0.024045  0.067084
# 22   35N_79W  0.025242  0.071644
# 23  40N_119W  0.033988  0.060838
# 24  40N_114W  0.036626  0.072086
# 25  40N_109W  0.036953  0.077410
# 26  40N_104W  0.041474  0.081378
# ...
